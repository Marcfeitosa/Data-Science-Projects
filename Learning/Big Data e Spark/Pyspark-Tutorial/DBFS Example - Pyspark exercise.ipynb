# %% [markdown]
# ## Overview
#
# This notebook will show you how to create and query a table or DataFrame that you uploaded to DBFS. [DBFS](https://docs.databricks.com/user-guide/dbfs-databricks-file-system.html) is a Databricks File System that allows you to store data for querying inside of Databricks. This notebook assumes that you have a file already inside of DBFS that you would like to read from.
#
# This notebook is written in **Python** so the default cell type is Python. However, you can use different languages by using the `%LANGUAGE` syntax. Python, Scala, SQL, and R are all supported.

# %%
# File location and type
file_location = "/FileStore/tables/tips.csv"
file_type = "csv"

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.csv(file_location,header=True,inferSchema=True)
df.show()
# Out:
# +----------+----+------+------+---+------+----+
# |total_bill| tip|   sex|smoker|day|  time|size|
# +----------+----+------+------+---+------+----+
# |     16.99|1.01|Female|    No|Sun|Dinner|   2|
# |     10.34|1.66|  Male|    No|Sun|Dinner|   3|
# |     21.01| 3.5|  Male|    No|Sun|Dinner|   3|
# |     23.68|3.31|  Male|    No|Sun|Dinner|   2|
# |     24.59|3.61|Female|    No|Sun|Dinner|   4|
# |     25.29|4.71|  Male|    No|Sun|Dinner|   4|
# |      8.77| 2.0|  Male|    No|Sun|Dinner|   2|
# |     26.88|3.12|  Male|    No|Sun|Dinner|   4|
# |     15.04|1.96|  Male|    No|Sun|Dinner|   2|
# |     14.78|3.23|  Male|    No|Sun|Dinner|   2|
# |     10.27|1.71|  Male|    No|Sun|Dinner|   2|
# |     35.26| 5.0|Female|    No|Sun|Dinner|   4|
# |     15.42|1.57|  Male|    No|Sun|Dinner|   2|
# |     18.43| 3.0|  Male|    No|Sun|Dinner|   4|
# |     14.83|3.02|Female|    No|Sun|Dinner|   2|
# |     21.58|3.92|  Male|    No|Sun|Dinner|   2|
# |     10.33|1.67|Female|    No|Sun|Dinner|   3|
# ...

# %%
# Create a view or table

temp_table_name = "tips_csv"

df.createOrReplaceTempView(temp_table_name)

# %%
# %sql

/* Query the created temp table in a SQL cell */

select * from `tips_csv`
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# With this registered as a temp view, it will only be available to this particular notebook. If you'd like other users to be able to query this table, you can also create a table from the DataFrame.
# Once saved, this table will persist across cluster restarts as well as allow various users across different notebooks to query this data.
# To do so, choose your table name and uncomment the bottom line.

permanent_table_name = "tips_csv"

# df.write.format("parquet").saveAsTable(permanent_table_name)

# %%
df.printSchema()
# Out:
# root
#  |-- total_bill: double (nullable = true)
#  |-- tip: double (nullable = true)
#  |-- sex: string (nullable = true)
#  |-- smoker: string (nullable = true)
#  |-- day: string (nullable = true)
#  |-- time: string (nullable = true)
#  |-- size: integer (nullable = true)

# %%
df.columns
# Out:
# Out[6]: ['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size']

# %%
# Handling Categorical features

from pyspark.ml.feature import StringIndexer

# %%
df.show()
# Out:
# +----------+----+------+------+---+------+----+
# |total_bill| tip|   sex|smoker|day|  time|size|
# +----------+----+------+------+---+------+----+
# |     16.99|1.01|Female|    No|Sun|Dinner|   2|
# |     10.34|1.66|  Male|    No|Sun|Dinner|   3|
# |     21.01| 3.5|  Male|    No|Sun|Dinner|   3|
# |     23.68|3.31|  Male|    No|Sun|Dinner|   2|
# |     24.59|3.61|Female|    No|Sun|Dinner|   4|
# |     25.29|4.71|  Male|    No|Sun|Dinner|   4|
# |      8.77| 2.0|  Male|    No|Sun|Dinner|   2|
# |     26.88|3.12|  Male|    No|Sun|Dinner|   4|
# |     15.04|1.96|  Male|    No|Sun|Dinner|   2|
# |     14.78|3.23|  Male|    No|Sun|Dinner|   2|
# |     10.27|1.71|  Male|    No|Sun|Dinner|   2|
# |     35.26| 5.0|Female|    No|Sun|Dinner|   4|
# |     15.42|1.57|  Male|    No|Sun|Dinner|   2|
# |     18.43| 3.0|  Male|    No|Sun|Dinner|   4|
# |     14.83|3.02|Female|    No|Sun|Dinner|   2|
# |     21.58|3.92|  Male|    No|Sun|Dinner|   2|
# |     10.33|1.67|Female|    No|Sun|Dinner|   3|
# ...

# %%
indexer=StringIndexer(inputCol="sex",outputCol='sex_indexed')
df_fited=indexer.fit(df).transform(df)
df_fited.show()
# Out:
# +----------+----+------+------+---+------+----+-----------+
# |total_bill| tip|   sex|smoker|day|  time|size|sex_indexed|
# +----------+----+------+------+---+------+----+-----------+
# |     16.99|1.01|Female|    No|Sun|Dinner|   2|        1.0|
# |     10.34|1.66|  Male|    No|Sun|Dinner|   3|        0.0|
# |     21.01| 3.5|  Male|    No|Sun|Dinner|   3|        0.0|
# |     23.68|3.31|  Male|    No|Sun|Dinner|   2|        0.0|
# |     24.59|3.61|Female|    No|Sun|Dinner|   4|        1.0|
# |     25.29|4.71|  Male|    No|Sun|Dinner|   4|        0.0|
# |      8.77| 2.0|  Male|    No|Sun|Dinner|   2|        0.0|
# |     26.88|3.12|  Male|    No|Sun|Dinner|   4|        0.0|
# |     15.04|1.96|  Male|    No|Sun|Dinner|   2|        0.0|
# |     14.78|3.23|  Male|    No|Sun|Dinner|   2|        0.0|
# |     10.27|1.71|  Male|    No|Sun|Dinner|   2|        0.0|
# |     35.26| 5.0|Female|    No|Sun|Dinner|   4|        1.0|
# |     15.42|1.57|  Male|    No|Sun|Dinner|   2|        0.0|
# ...

# %%
indexer=StringIndexer(inputCols=["smoker","day","time"],outputCols=["smoker_indexed","day_indexed","time_indexed"])
df_fited=indexer.fit(df_fited).transform(df_fited)
df_fited.show()
# Out:
# +----------+----+------+------+---+------+----+-----------+--------------+-----------+------------+
# |total_bill| tip|   sex|smoker|day|  time|size|sex_indexed|smoker_indexed|day_indexed|time_indexed|
# +----------+----+------+------+---+------+----+-----------+--------------+-----------+------------+
# |     16.99|1.01|Female|    No|Sun|Dinner|   2|        1.0|           0.0|        1.0|         0.0|
# |     10.34|1.66|  Male|    No|Sun|Dinner|   3|        0.0|           0.0|        1.0|         0.0|
# |     21.01| 3.5|  Male|    No|Sun|Dinner|   3|        0.0|           0.0|        1.0|         0.0|
# |     23.68|3.31|  Male|    No|Sun|Dinner|   2|        0.0|           0.0|        1.0|         0.0|
# |     24.59|3.61|Female|    No|Sun|Dinner|   4|        1.0|           0.0|        1.0|         0.0|
# |     25.29|4.71|  Male|    No|Sun|Dinner|   4|        0.0|           0.0|        1.0|         0.0|
# ...

# %%
df_fited.columns
# Out:
# Out[14]: ['total_bill',
#  'tip',
#  'sex',
#  'smoker',
#  'day',
#  'time',
#  'size',
#  'sex_indexed',
#  'smoker_indexed',
#  'day_indexed',
#  'time_indexed']

# %%
from pyspark.ml.feature import VectorAssembler
featureassembler = VectorAssembler(inputCols=['tip','size','smoker_indexed','smoker_indexed','day_indexed','time_indexed'],outputCol="Independent-Features")
output=featureassembler.transform(df_fited)

# %%
output.show()
# Out:
# +----------+----+------+------+---+------+----+-----------+--------------+-----------+------------+--------------------+
# |total_bill| tip|   sex|smoker|day|  time|size|sex_indexed|smoker_indexed|day_indexed|time_indexed|Independent-Features|
# +----------+----+------+------+---+------+----+-----------+--------------+-----------+------------+--------------------+
# |     16.99|1.01|Female|    No|Sun|Dinner|   2|        1.0|           0.0|        1.0|         0.0|[1.01,2.0,0.0,0.0...|
# |     10.34|1.66|  Male|    No|Sun|Dinner|   3|        0.0|           0.0|        1.0|         0.0|[1.66,3.0,0.0,0.0...|
# |     21.01| 3.5|  Male|    No|Sun|Dinner|   3|        0.0|           0.0|        1.0|         0.0|[3.5,3.0,0.0,0.0,...|
# |     23.68|3.31|  Male|    No|Sun|Dinner|   2|        0.0|           0.0|        1.0|         0.0|[3.31,2.0,0.0,0.0...|
# |     24.59|3.61|Female|    No|Sun|Dinner|   4|        1.0|           0.0|        1.0|         0.0|[3.61,4.0,0.0,0.0...|
# ...

# %%
output.select('Independent-Features').show()
# Out:
# +--------------------+
# |Independent-Features|
# +--------------------+
# |[1.01,2.0,0.0,0.0...|
# |[1.66,3.0,0.0,0.0...|
# |[3.5,3.0,0.0,0.0,...|
# |[3.31,2.0,0.0,0.0...|
# |[3.61,4.0,0.0,0.0...|
# |[4.71,4.0,0.0,0.0...|
# |[2.0,2.0,0.0,0.0,...|
# |[3.12,4.0,0.0,0.0...|
# |[1.96,2.0,0.0,0.0...|
# |[3.23,2.0,0.0,0.0...|
# |[1.71,2.0,0.0,0.0...|
# |[5.0,4.0,0.0,0.0,...|
# |[1.57,2.0,0.0,0.0...|
# |[3.0,4.0,0.0,0.0,...|
# |[3.02,2.0,0.0,0.0...|
# |[3.92,2.0,0.0,0.0...|
# |[1.67,3.0,0.0,0.0...|
# |[3.71,3.0,0.0,0.0...|
# |[3.5,3.0,0.0,0.0,...|
# |(6,[0,1],[3.35,3.0])|
# +--------------------+
# only showing top 20 rows

# %%
output.show()
# Out:
# +----------+----+------+------+---+------+----+-----------+--------------+-----------+------------+--------------------+
# |total_bill| tip|   sex|smoker|day|  time|size|sex_indexed|smoker_indexed|day_indexed|time_indexed|Independent-Features|
# +----------+----+------+------+---+------+----+-----------+--------------+-----------+------------+--------------------+
# |     16.99|1.01|Female|    No|Sun|Dinner|   2|        1.0|           0.0|        1.0|         0.0|[1.01,2.0,0.0,0.0...|
# |     10.34|1.66|  Male|    No|Sun|Dinner|   3|        0.0|           0.0|        1.0|         0.0|[1.66,3.0,0.0,0.0...|
# |     21.01| 3.5|  Male|    No|Sun|Dinner|   3|        0.0|           0.0|        1.0|         0.0|[3.5,3.0,0.0,0.0,...|
# |     23.68|3.31|  Male|    No|Sun|Dinner|   2|        0.0|           0.0|        1.0|         0.0|[3.31,2.0,0.0,0.0...|
# |     24.59|3.61|Female|    No|Sun|Dinner|   4|        1.0|           0.0|        1.0|         0.0|[3.61,4.0,0.0,0.0...|
# ...

# %%
finalized_data = output.select('Independent-Features','total_bill')

# %%
finalized_data.show()
# Out:
# +--------------------+----------+
# |Independent-Features|total_bill|
# +--------------------+----------+
# |[1.01,2.0,0.0,0.0...|     16.99|
# |[1.66,3.0,0.0,0.0...|     10.34|
# |[3.5,3.0,0.0,0.0,...|     21.01|
# |[3.31,2.0,0.0,0.0...|     23.68|
# |[3.61,4.0,0.0,0.0...|     24.59|
# |[4.71,4.0,0.0,0.0...|     25.29|
# |[2.0,2.0,0.0,0.0,...|      8.77|
# |[3.12,4.0,0.0,0.0...|     26.88|
# |[1.96,2.0,0.0,0.0...|     15.04|
# |[3.23,2.0,0.0,0.0...|     14.78|
# |[1.71,2.0,0.0,0.0...|     10.27|
# |[5.0,4.0,0.0,0.0,...|     35.26|
# |[1.57,2.0,0.0,0.0...|     15.42|
# |[3.0,4.0,0.0,0.0,...|     18.43|
# |[3.02,2.0,0.0,0.0...|     14.83|
# |[3.92,2.0,0.0,0.0...|     21.58|
# |[1.67,3.0,0.0,0.0...|     10.33|
# |[3.71,3.0,0.0,0.0...|     16.29|
# |[3.5,3.0,0.0,0.0,...|     16.97|
# |(6,[0,1],[3.35,3.0])|     20.65|
# +--------------------+----------+
# only showing top 20 rows

# %%
from pyspark.ml.regression import LinearRegression
# Train test split
train_data,test_data = finalized_data.randomSplit([0.75,0.25])
regressor=LinearRegression(featuresCol='Independent-Features', labelCol='total_bill')
regressor=regressor.fit(train_data)

# %%
regressor.coefficients
# Out:
# Out[23]: DenseVector([3.2773, 3.2647, 0.7764, 0.7764, 0.1188, -1.783])

# %%
regressor.intercept
# Out:
# Out[24]: 0.7590253559364456

# %%
# Predictions
pred_results=regressor.evaluate(test_data)

# %%
## Final Comparison
pred_results.predictions.show()
# Out:
# +--------------------+----------+------------------+
# |Independent-Features|total_bill|        prediction|
# +--------------------+----------+------------------+
# | (6,[0,1],[2.0,2.0])|     12.69|13.843079939386717|
# |(6,[0,1],[2.34,4.0])|     17.81| 21.48673702841999|
# |(6,[0,1],[2.45,4.0])|     20.69|21.847245296122324|
# | (6,[0,1],[2.5,4.0])|     18.35| 22.01111269053247|
# |(6,[0,1],[3.35,3.0])|     20.65|21.532178991982903|
# |(6,[0,1],[4.67,3.0])|     35.83|25.858278204410876|
# |(6,[0,1],[5.92,3.0])|     29.03| 29.95496306466464|
# | (6,[0,1],[9.0,4.0])|     48.33| 43.31387396385203|
# |[1.0,2.0,1.0,1.0,...|      12.6|12.118438170452908|
# |[1.0,2.0,1.0,1.0,...|      5.75|12.474923579171884|
# |[1.01,2.0,0.0,0.0...|     16.99|10.717333999638731|
# |[1.17,2.0,1.0,1.0...|     32.83| 12.67558731144742|
# |[1.36,3.0,0.0,0.0...|     18.64|13.464897555104905|
# |[1.48,2.0,0.0,0.0...|      8.52|10.593499898167138|
# |[1.5,2.0,0.0,0.0,...|     19.08|10.659046855931198|
# ...

# %%
# Performance Metrics
pred_results.r2,pred_results.meanAbsoluteError,pred_results.meanSquaredError
# Out:
# Out[28]: (0.39600508937785117, 5.495614968055095, 60.856635289976474)

# %%
import pickle

# you should insert the DataFrame name you are using here
data = finalized_data.collect()

with open("mydata.pkl", "wb") as f:
    pickle.dump(data, f)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <command-1233028292414819> in <cell line: 4>()
#       2
#       3 # you should insert the DataFrame name you are using here
# ----> 4 data = pred_results.collect()
#       5
#       6 with open("mydata.pkl", "wb") as f:
#
# AttributeError: 'LinearRegressionSummary' object has no attribute 'collect'
