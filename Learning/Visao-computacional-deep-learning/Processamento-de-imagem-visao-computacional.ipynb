# %% [markdown]
# # Visão computacional e Deep Learning

# %% [markdown]
# ## Instalando a biblioteca pillow

# %%
# !pip install pillow

# %%
# !pip install --upgrade Pillow
# Out:
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 8.2.0
#     Uninstalling Pillow-8.2.0:
#       Successfully uninstalled Pillow-8.2.0
# ...

# %%
import PIL
import os

# %% [markdown]
# ### Verificando as versões instaladas

# %%
print('Pillow Version: ', PIL.__version__)
print('PIL Version: ', PIL)
# Out:
# Pillow Version:  9.4.0
# PIL Version:  <module 'PIL' from 'C:\\Users\\marcf\\anaconda3\\lib\\site-packages\\PIL\\__init__.py'>

# %% [markdown]
# ## Classe para fazer a manipulação de imagens

# %%
from PIL import Image

# %% [markdown]
# ### Carregar um imagem a partir do disco

# %%
image = Image.open(r"C:\Users\marcf\OneDrive\Documentos\Ciencia de dados\Visao-computacional-deep-learning\materiais-apoio-01\imagens\new-york.jpg")

# %% [markdown]
# ### Visualizando a imagem no console do Jupyter Lab

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=639x358>

# %% [markdown]
# ### Visualizando a imagem no sistema operacional

# %%
image.show()

# %% [markdown]
# ### Exibir propriedades da imagem

# %% [markdown]
# #### Imprmindo o formato da imagem

# %%
print(image.format)
# Out:
# JPEG

# %% [markdown]
# #### Imprimindo o canal do formato de pixels

# %%
print(image.mode)
# Out:
# RGB

# %% [markdown]
# #### Imprimindo as dimensções da imagem em pixels

# %%
print(image.size)
# Out:
# (639, 358)

# %% [markdown]
# ## Pixel e estrutura de dados de imagens
#
# - **Pixel** é a menor unidade RGB, o pixel é representado por três números de 8 bits associados com as cores **R,G e B** que correspondem às cores **RED**, **GREEN** e **BLUE** respectivamente.
#
# - Como são números de 8 bits a faixa de valores é de **0 até 255**

# %%
Image.open(r"C:\Users\marcf\OneDrive\Documentos\Ciencia de dados\Visao-computacional-deep-learning\materiais-apoio-01\imagens\pixel-rgb.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=724x284>

# %% [markdown]
# A cor do Pixel será gerada a partir da combinação de cada um dos canais.
#
# Se a combinação de valores for 255 a cor do pixel será **branco**, se a combinação for 0, a cor do Pixel será **Preto**.

# %% [markdown]
# ![rgb_gif](rgb_gif.gif)

# %% [markdown]
# ## Convertendo imagens para arrays Numpy

# %% [markdown]
# ### importando as bilbliotecas para visualização das imagens

# %%
from matplotlib import image
from matplotlib import pyplot

# %% [markdown]
# ### Carregando imagem como umarray Numpy

# %%
data = image.imread(r"C:\Users\marcf\OneDrive\Documentos\Ciencia de dados\Visao-computacional-deep-learning\materiais-apoio-01\imagens\new-york.jpg")

# %% [markdown]
# ### imprimindo o conteúdo do array Numpy

# %%
print(data)
# Out:
# [[[148 188 188]
#   [148 188 188]
#   [148 188 188]
#   ...
#   [119 145 146]
#   [119 145 146]
#   [119 145 144]]
#
#  [[149 189 189]
#   [149 189 189]
#   [149 189 189]
#   ...
#   [119 145 146]
#   [119 145 146]
#   [118 144 143]]
#
#  [[150 190 190]
#   [150 190 190]
#   [150 190 190]
#   ...
#   [118 144 145]
#   [118 144 145]
#   [118 144 145]]
#
#  ...
#
#  [[132 137 105]
#   [129 134 102]
#   [124 131 100]
#   ...
#   [ 15  23  44]
#   [ 15  27  49]
#   [ 22  39  57]]
#
#  [[129 134 102]
#   [128 133 101]
#   [123 130  99]
#   ...
#   [ 64  65  85]
#   [ 51  53  74]
#   [ 38  46  67]]
#
#  [[124 129  97]
#   [125 130  98]
#   [125 132 101]
#   ...
#   [ 36  32  49]
#   [ 44  42  63]
#   [ 49  54  76]]]

# %% [markdown]
# ### imprimindo as propriedades do array pixels

# %%
print(data.dtype)
# Out:
# uint8

# %%
print(data.shape)
# Out:
# (358, 639, 3)

# %%
print(data.max())
# Out:
# 255

# %%
print(data.min())
# Out:
# 0

# %% [markdown]
# ### exibindo o array de pixels como uma imagem

# %%
pyplot.imshow(data);

# %% [markdown]
# ### convertendo o array de pixels em um objeto Image Pillow

# %%
image2 = Image.fromarray(data)

# %% [markdown]
# ### verificando o tipo de objeto

# %%
type(image2)
# Out:
# PIL.Image.Image

# %% [markdown]
# ### convertendo um objeto do tipo imagem para um array numpy

# %%
from numpy import asarray

# %%
image = Image.open(r"C:\Users\marcf\OneDrive\Documentos\Ciencia de dados\Visao-computacional-deep-learning\materiais-apoio-01\imagens\new-york.jpg")

# %% [markdown]
# ### Método asarray para realizar a conversão

# %%
data = asarray(image)

# %% [markdown]
# #### Imprimindo os atributos do array

# %%
print(data.dtype)
print(data.shape)
# Out:
# uint8
# (358, 639, 3)

# %% [markdown]
# ### Salvando as imagens em disco
#
# - Salvando a imagem no formato PNG

# %%
image.save(r"C:\Users\marcf\OneDrive\Documentos\Ciencia de dados\Visao-computacional-deep-learning\materiais-apoio-01\imagens\new-york.png",
           format='PNG')

# %% [markdown]
# - Salvando a imagem no formato GIF

# %%
image.save(r"C:\Users\marcf\OneDrive\Documentos\Ciencia de dados\Visao-computacional-deep-learning\materiais-apoio-01\imagens\new-york.gif",
           format='GIF')

# %% [markdown]
# - Carregando novamente a imagem e verificando o formato

# %%
image3 = Image.open(r"C:\Users\marcf\OneDrive\Documentos\Ciencia de dados\Visao-computacional-deep-learning\materiais-apoio-01\imagens\new-york.gif")

# %%
print(image3.format)
# Out:
# GIF

# %% [markdown]
# ### Convertendo imagens
#
# - Convertendo a imagem em escala de cinza

# %%
image_cinza = image.convert(mode='L')
image_cinza
# Out:
# <PIL.Image.Image image mode=L size=639x358>

# %% [markdown]
# - Salvando a imagem em disco

# %%
image_cinza.save(r"C:\Users\marcf\OneDrive\Documentos\Ciencia de dados\Visao-computacional-deep-learning\materiais-apoio-01\imagens\new-york-cinza.png")

# %% [markdown]
# #### Resiza Imagens
#
# - Verificando o tamanho da imagem com o atributo size

# %%
print(image.size)
# Out:
# (639, 358)

# %% [markdown]
# - Gerando thambnail de tamanho 100,100

# %%
image.thumbnail((100,100))
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x56>

# %% [markdown]
# - Verifficando as novas dimensões

# %%
print(image.size)
# Out:
# (100, 56)

# %% [markdown]
# - Carregando novamente a image

# %%
image = Image.open(r"C:\Users\marcf\OneDrive\Documentos\Ciencia de dados\Visao-computacional-deep-learning\materiais-apoio-01\imagens\new-york.jpg")

# %% [markdown]
# - resize a imagem ignorando o aspecto ratio

# %%
image_resize = image.resize((200,200))

# %% [markdown]
# - Verificando as novas dimensões

# %%
print(image_resize.size)
# Out:
# (200, 200)

# %%
pyplot.imshow(image_resize)

# %% [markdown]
# ### Invertendo Imagens(Flip)

# %% [markdown]
# - Inversão horizontal

# %%
horizontal_image = image.transpose(Image.FLIP_LEFT_RIGHT)

# %% [markdown]
# - Visualizando a imagem

# %%
pyplot.imshow(horizontal_image)

# %% [markdown]
# - Inversão vertical

# %%
vertical_image = image.transpose(Image.FLIP_TOP_BOTTOM)

# %% [markdown]
# - visualizando a image

# %%
pyplot.imshow(vertical_image)

# %% [markdown]
# - Girar Imagens (Rotate)

# %%
# carregando novamente

image = Image.open(r"C:\Users\marcf\OneDrive\Documentos\Ciencia de dados\Visao-computacional-deep-learning\materiais-apoio-01\imagens\new-york.jpg")

# %% [markdown]
# - rotacionando a imagem em 45 graus

# %%
pyplot.imshow(image.rotate(45))

# %% [markdown]
# - Rotacionando a imagem em 90 graus

# %%
pyplot.imshow(image.rotate(90))

# %% [markdown]
# ### Cortar Imagens (Crop)

# %% [markdown]
# - exibindo a imagem original

# %%
pyplot.imshow(image)

# %% [markdown]
# - Exibindo o corte da imagem a partir das coordenadas especificadas - left, upper, right and lower

# %%
pyplot.imshow(image.crop((100,100,200,200)))

# %% [markdown]
# ## Técnicas de pré-processamento aplicado a imagens
#
# - Normalizando valores de pixels

# %%
image = Image.open(r"C:\Users\marcf\OneDrive\Documentos\Ciencia de dados\Visao-computacional-deep-learning\materiais-apoio-01\imagens\new-york.jpg")

# %% [markdown]
# - convertendo a imagem em um array

# %%
pixels = asarray(image)

# %% [markdown]
# - verificando a faixa de valores entre 0 e 255

# %%
print('Data Type: %s' % pixels.dtype)
print('Min: %.3f, Max %.3f' % (pixels.min(), pixels.max()))
# Out:
# Data Type: uint8
# Min: 0.000, Max 255.000

# %% [markdown]
# - converte os valores inteiros em float para realizar a operação

# %%
pixels = pixels.astype('float32')

# %% [markdown]
# - normaliza a faixa de valores

# %%
pixels /= pixels.max()

# %% [markdown]
# - verificando a faixa de valores normalizada

# %%
print('data type: %s' % pixels.dtype)
print('Min: %.3f, Max %.3f' % (pixels.min(), pixels.max()))
# Out:
# data type: float32
# Min: 0.000, Max 1.000
